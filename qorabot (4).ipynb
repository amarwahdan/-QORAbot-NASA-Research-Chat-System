# %% [markdown]
# # **Installation libraries**

# %%
# !pip install -U langchain-community
# !pip install faiss-cpu
# !pip install sentence-transformers
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.30-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=0.3.75 (from langchain-community)
#   Downloading langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain<2.0.0,>=0.3.27 (from langchain-community)
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.6.7)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<2.0.0,>=0.3.27->langchain-community)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (4.14.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<2.0.0,>=0.3.75->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.2->langchain-community) (2.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<2.0.0,>=0.3.75->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.2->langchain-community) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.2->langchain-community) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.26.2->langchain-community) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.26.2->langchain-community) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.26.2->langchain-community) (2024.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.30-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 47.9 MB/s eta 0:00:0000:01
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.76-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 27.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.2 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: requests, python-dotenv, httpx-sse, pydantic-settings, langchain-core, langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.66
#     Uninstalling langchain-core-0.3.66:
#       Successfully uninstalled langchain-core-0.3.66
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.8
#     Uninstalling langchain-text-splitters-0.3.8:
#       Successfully uninstalled langchain-text-splitters-0.3.8
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.26
#     Uninstalling langchain-0.3.26:
#       Successfully uninstalled langchain-0.3.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# Successfully installed httpx-sse-0.4.1 langchain-0.3.27 langchain-community-0.3.30 langchain-core-0.3.76 langchain-text-splitters-0.3.11 pydantic-settings-2.11.0 python-dotenv-1.1.1 requests-2.32.5
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 54.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.33.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.8 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# # **Import libraries**

# %%
import pandas as pd
import numpy as np
import os
from typing import List, Dict, Any
# LangChain
from langchain_community.document_loaders import DataFrameLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.llms import HuggingFacePipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.chains import RetrievalQA
from langchain_community.llms import Ollama
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline, AutoModelForCausalLM

# %%
# Load NASA Data
def clean_text(text):
    if not isinstance(text, str):
        text = str(text)

    replacements = {
        'â€™': "'",
        'â€œ': '"',
        'â€': '"',
        'Â°': '°',
        'Â²': '²',
        'Â³': '³'
    }

    for old, new in replacements.items():
        text = text.replace(old, new)

    return text.strip()

# %% [markdown]
# # **Load NASA Data**

# %%
# Load Data
NASA = pd.read_csv("/kaggle/input/nasadata/NASA DATA.csv")
NASA.head()

# Clean the text columns
NASA['question'] = NASA['question'].apply(clean_text)
NASA['answer'] = NASA['answer'].apply(clean_text)

# Create Text Col
NASA['text'] = NASA['question'] + " " + NASA['answer']

# Select Columns
NASA = NASA[['category','question','answer','source','text']]
NASA
# Out:
#     category                                           question  \
# 0       NASA                                      What is NASA?
# 1       NASA                             When was NASA founded?
# 2       NASA                          What does NASA stand for?
# 3       NASA                        What are NASA’s main goals?
# 4        ISS     What is the International Space Station (ISS)?
# ..       ...                                                ...
# 372     NASA  How are astronaut candidates evaluated during ...
# 373     NASA  What swimming strokes are tested during astron...
# 374     NASA  Do NASA astronauts train for spacewalk emergen...
# 375     NASA  Are astronauts trained for fire emergencies on...
# 376     NASA  Do astronaut candidates receive leadership tra...
#
#                                                 answer  \
# 0    NASA is the United States government agency re...
# 1    NASA was founded on July 29, 1958, through the...
# 2    NASA stands for National Aeronautics and Space...
# 3    NASA’s goals include space exploration, Earth ...
# 4    The ISS is a habitable artificial satellite an...
# ..                                                 ...
# 372  They are assessed on technical knowledge, team...
# 373  Candidates are tested using freestyle, backstr...
# 374  Yes, training covers contingencies such as sui...
# 375  Yes, they undergo emergency training for fire,...
# 376  Yes, they train in leadership, teamwork, and c...
#
#                                                 source  \
# 0                                 https://www.nasa.gov
# 1                                 https://www.nasa.gov
# 2                                 https://www.nasa.gov
# 3                                 https://www.nasa.gov
# 4                             https://www.nasa.gov/iss
# ..                                                 ...
# 372  https://en.wikipedia.org/wiki/List_of_astronau...
# 373  https://en.wikipedia.org/wiki/List_of_astronau...
# 374  https://en.wikipedia.org/wiki/List_of_astronau...
# 375  https://en.wikipedia.org/wiki/List_of_astronau...
# 376  https://en.wikipedia.org/wiki/List_of_astronau...
#
#                                                   text
# 0    What is NASA? NASA is the United States govern...
# 1    When was NASA founded? NASA was founded on Jul...
# 2    What does NASA stand for? NASA stands for Nati...
# 3    What are NASA’s main goals? NASA’s goals inclu...
# 4    What is the International Space Station (ISS)?...
# ..                                                 ...
# 372  How are astronaut candidates evaluated during ...
# 373  What swimming strokes are tested during astron...
# 374  Do NASA astronauts train for spacewalk emergen...
# 375  Are astronauts trained for fire emergencies on...
# 376  Do astronaut candidates receive leadership tra...
#
# [377 rows x 5 columns]

# %%
NASA['text'][230], len(NASA['text'][230])
# Out:
# ('How long did the Saffire fire safety experiments run? The Saffire experiments began in 2016 and concluded in 2024, spanning multiple missions.',
#  142)

# %%
# Data Overview
display("Data size:", NASA.shape)
print('--------------------------------------------')
display("\n columns:", NASA.columns.tolist())
print('--------------------------------------------')
display("\n Data type:", NASA.dtypes)
print('--------------------------------------------')
# Out:
# 'Data size:'
# (377, 5)
# --------------------------------------------
# '\n columns:'
# ['category', 'question', 'answer', 'source', 'text']
# --------------------------------------------
# '\n Data type:'
# category    object
# question    object
# answer      object
# source      object
# text        object
# dtype: object
# --------------------------------------------

# %%
NASA['category'].value_counts()
# Out:
# category
# ISS         94
# Research    90
# NASA        79
# EVA         71
# NBL         43
# Name: count, dtype: int64

# %% [markdown]
# # **RAG Documents Loading and Chunking**

# %%
# Create LangChain Document
LLM_Loader = DataFrameLoader(NASA, page_content_column="answer")
LLM_Data = LLM_Loader.load()
LLM_Data[1].model_dump()
# Out:
# {'id': None,
#  'metadata': {'category': 'NASA',
#   'question': 'When was NASA founded?',
#   'source': 'https://www.nasa.gov',
#   'text': 'When was NASA founded? NASA was founded on July 29, 1958, through the National Aeronautics and Space Act.'},
#  'page_content': 'NASA was founded on July 29, 1958, through the National Aeronautics and Space Act.',
#  'type': 'Document'}

# %%
len(LLM_Data)
# Out:
# 377

# %% [markdown]
# # **Chunking**

# %%
# Text Splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=200,
    length_function=len,
    separators=["\n", ".", " "]
)
Chunk = text_splitter.split_documents(LLM_Data)
Chunk
# Out:
# [Document(metadata={'category': 'NASA', 'question': 'What is NASA?', 'source': 'https://www.nasa.gov', 'text': 'What is NASA? NASA is the United States government agency responsible for space exploration, aeronautics research, and scientific discovery. It was established in 1958.'}, page_content='NASA is the United States government agency responsible for space exploration, aeronautics research, and scientific discovery. It was established in 1958.'),
#  Document(metadata={'category': 'NASA', 'question': 'When was NASA founded?', 'source': 'https://www.nasa.gov', 'text': 'When was NASA founded? NASA was founded on July 29, 1958, through the National Aeronautics and Space Act.'}, page_content='NASA was founded on July 29, 1958, through the National Aeronautics and Space Act.'),
#  Document(metadata={'category': 'NASA', 'question': 'What does NASA stand for?', 'source': 'https://www.nasa.gov', 'text': 'What does NASA stand for? NASA stands for National Aeronautics and Space Administration.'}, page_content='NASA stands for National Aeronautics and Space Administration.'),
#  Document(metadata={'category': 'NASA', 'question': 'What are NASA’s main goals?', 'source': 'https://www.nasa.gov', 'text': 'What are NASA’s main goals? NASA’s goals include space exploration, Earth observation, scientific research, developing new technologies, and preparing for future missions to the Moon and Mars.'}, page_content='NASA’s goals include space exploration, Earth observation, scientific research, developing new technologies, and preparing for future missions to the Moon and Mars.'),
#  Document(metadata={'category': 'ISS', 'question': 'What is the International Space Station (ISS)?', 'source': 'https://www.nasa.gov/iss', 'text': 'What is the International Space Station (ISS)? The ISS is a habitable artificial satellite and space laboratory orbiting Earth at about 400 km altitude, where astronauts conduct experiments in microgravity.'}, page_content='The ISS is a habitable artificial satellite and space laboratory orbiting Earth at about 400 km altitude, where astronauts conduct experiments in microgravity.'),
#  Document(metadata={'category': 'ISS', 'question': 'How fast does the ISS orbit Earth?', 'source': 'https://spotthestation.nasa.gov', 'text': 'How fast does the ISS orbit Earth? The ISS orbits Earth at a speed of about 28,000 km/h (17,500 mph), completing one orbit every 90 minutes.'}, page_content='The ISS orbits Earth at a speed of about 28,000 km/h (17,500 mph), completing one orbit every 90 minutes.'),
#  Document(metadata={'category': 'ISS', 'question': 'How many sunrises and sunsets do astronauts see each day on ISS?', 'source': 'https://www.nasa.gov/iss', 'text': 'How many sunrises and sunsets do astronauts see each day on ISS? Astronauts onboard the ISS see about 16 sunrises and sunsets every 24 hours due to the station’s high orbital speed.'}, page_content='Astronauts onboard the ISS see about 16 sunrises and sunsets every 24 hours due to the station’s high orbital speed.'),
#  Document(metadata={'category': 'ISS', 'question': 'Why is the ISS important for science?', 'source': 'https://www.nasa.gov/iss-science', 'text': 'Why is the ISS important for science? The ISS allows scientists to study biology, physics, astronomy, and Earth science in microgravity, and helps test technologies for future deep space missions.'}, page_content='The ISS allows scientists to study biology, physics, astronomy, and Earth science in microgravity, and helps test technologies for future deep space missions.'),
#  Document(metadata={'category': 'NBL', 'question': 'What is the Neutral Buoyancy Laboratory (NBL)?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory', 'text': 'What is the Neutral Buoyancy Laboratory (NBL)? The NBL is a large pool facility at NASA’s Johnson Space Center in Houston, Texas, where astronauts train underwater to simulate the weightlessness of space.'}, page_content='The NBL is a large pool facility at NASA’s Johnson Space Center in Houston, Texas, where astronauts train underwater to simulate the weightlessness of space.'),
#  Document(metadata={'category': 'NBL', 'question': 'How big is the NBL?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory', 'text': 'How big is the NBL? The NBL holds 6.2 million gallons of water, measuring 62 m (202 ft) long, 31 m (102 ft) wide, and 12 m (40 ft) deep.'}, page_content='The NBL holds 6.2 million gallons of water, measuring 62 m (202 ft) long, 31 m (102 ft) wide, and 12 m (40 ft) deep.'),
#  Document(metadata={'category': 'NBL', 'question': 'Why do astronauts train in the NBL?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory', 'text': 'Why do astronauts train in the NBL? Astronauts use the NBL to practice spacewalks (EVAs) and learn how to move, repair equipment, and handle tools in a simulated microgravity environment.'}, page_content='Astronauts use the NBL to practice spacewalks (EVAs) and learn how to move, repair equipment, and handle tools in a simulated microgravity environment.'),
#  Document(metadata={'category': 'EVA', 'question': 'What does EVA stand for?', 'source': 'https://www.nasa.gov/suitup', 'text': 'What does EVA stand for? EVA stands for Extravehicular Activity, which refers to astronauts leaving their spacecraft to work in space, usually called a spacewalk.'}, page_content='EVA stands for Extravehicular Activity, which refers to astronauts leaving their spacecraft to work in space, usually called a spacewalk.'),
#  Document(metadata={'category': 'EVA', 'question': 'How do astronauts prepare for EVAs?', 'source': 'https://www.nasa.gov/suitup', 'text': 'How do astronauts prepare for EVAs? Astronauts spend hours training in the NBL, learning how to move safely, use tools, and complete tasks like repairing equipment or installing modules.'}, page_content='Astronauts spend hours training in the NBL, learning how to move safely, use tools, and complete tasks like repairing equipment or installing modules.'),
#  Document(metadata={'category': 'ISS', 'question': 'How many spacewalks have been conducted on the ISS?', 'source': 'https://www.nasa.gov/iss', 'text': 'How many spacewalks have been conducted on the ISS? Since 1998, there have been more than 270 spacewalks at the International Space Station.'}, page_content='Since 1998, there have been more than 270 spacewalks at the International Space Station.'),
#  Document(metadata={'category': 'NASA', 'question': 'What are some NASA achievements?', 'source': 'https://www.nasa.gov', 'text': 'What are some NASA achievements? NASA has landed humans on the Moon (Apollo), launched the Space Shuttle, sent probes like Voyager, and developed telescopes like Hubble and James Webb.'}, page_content='NASA has landed humans on the Moon (Apollo), launched the Space Shuttle, sent probes like Voyager, and developed telescopes like Hubble and James Webb.'),
#  Document(metadata={'category': 'NBL', 'question': 'What is the Neutral Buoyancy Laboratory (NBL)?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What is the Neutral Buoyancy Laboratory (NBL)? The NBL is NASA’s large underwater training facility located near the Johnson Space Center in Houston. It is used to simulate weightlessness and prepare astronauts for spacewalks (EVAs).'}, page_content='The NBL is NASA’s large underwater training facility located near the Johnson Space Center in Houston. It is used to simulate weightlessness and prepare astronauts for spacewalks (EVAs).'),
#  Document(metadata={'category': 'NBL', 'question': 'Why is the NBL important?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'Why is the NBL important? The NBL allows astronauts to practice complex tasks in a safe environment by simulating microgravity using neutral buoyancy. This helps prepare them physically, mentally, and technically for real space missions.'}, page_content='The NBL allows astronauts to practice complex tasks in a safe environment by simulating microgravity using neutral buoyancy. This helps prepare them physically, mentally, and technically for real space missions.'),
#  Document(metadata={'category': 'NBL', 'question': 'When did NASA start using neutral buoyancy for astronaut training?', 'source': 'https://en.wikipedia.org/wiki/Astronaut_training', 'text': 'When did NASA start using neutral buoyancy for astronaut training? NASA began using water tanks to simulate weightlessness in the late 1960s, during programs such as Gemini and Skylab. The NBL officially opened in 1995.'}, page_content='NASA began using water tanks to simulate weightlessness in the late 1960s, during programs such as Gemini and Skylab. The NBL officially opened in 1995.'),
#  Document(metadata={'category': 'NBL', 'question': 'How big is the NBL?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'How big is the NBL? The NBL is 202 feet (62 m) long, 102 feet (31 m) wide, and 40 feet (12 m) deep, holding 6.2 million gallons of water.'}, page_content='The NBL is 202 feet (62 m) long, 102 feet (31 m) wide, and 40 feet (12 m) deep, holding 6.2 million gallons of water.'),
#  Document(metadata={'category': 'NBL', 'question': 'What training stages do astronauts follow in the NBL?', 'source': 'https://appel.nasa.gov/podcast/episode-108-underwater-training-for-astronauts/', 'text': 'What training stages do astronauts follow in the NBL? Astronauts first learn swimming and water survival, then move to endurance-building dives, then mission-specific and emergency simulations, and finally refresher training to maintain skills.'}, page_content='Astronauts first learn swimming and water survival, then move to endurance-building dives, then mission-specific and emergency simulations, and finally refresher training to maintain skills.'),
#  Document(metadata={'category': 'NBL', 'question': 'What tasks do astronauts practice in the NBL?', 'source': 'https://scitechdaily.com/astronauts-prepare-to-tackle-critical-repairs-in-historic-iss-spacewalk/', 'text': 'What tasks do astronauts practice in the NBL? Astronauts practice repairing ISS components, replacing hardware, installing upgrades, moving along handrails, and using specialized tools underwater.'}, page_content='Astronauts practice repairing ISS components, replacing hardware, installing upgrades, moving along handrails, and using specialized tools underwater.'),
#  Document(metadata={'category': 'NBL', 'question': 'What scientific principle does NBL training rely on?', 'source': 'https://smv.org/documents/303/Astronaut_Lesson_Plan_Buoyancy.pdf', 'text': 'What scientific principle does NBL training rely on? It relies on Archimedes’ principle of buoyancy, where a submerged body experiences an upward force equal to the weight of displaced fluid. By adjusting weights, astronauts achieve neutral buoyancy, simulating microgravity.'}, page_content='It relies on Archimedes’ principle of buoyancy, where a submerged body experiences an upward force equal to the weight of displaced fluid. By adjusting weights, astronauts achieve neutral buoyancy, simulating microgravity.'),
#  Document(metadata={'category': 'NBL', 'question': 'What are the main strengths of NBL training?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What are the main strengths of NBL training? NBL training provides long-duration microgravity simulation, full-scale ISS mockups, and safe, repeatable practice of complex tasks.'}, page_content='NBL training provides long-duration microgravity simulation, full-scale ISS mockups, and safe, repeatable practice of complex tasks.'),
#  Document(metadata={'category': 'NBL', 'question': 'What are the limitations of NBL training?', 'source': 'https://pmc.ncbi.nlm.nih.gov/articles/PMC10257652/', 'text': 'What are the limitations of NBL training? Unlike real space, water drag slows astronaut movements, tactile and vestibular cues differ, and the astronaut still feels suit weight inside. Thus, NBL is not a perfect simulation.'}, page_content='Unlike real space, water drag slows astronaut movements, tactile and vestibular cues differ, and the astronaut still feels suit weight inside. Thus, NBL is not a perfect simulation.'),
#  Document(metadata={'category': 'NBL', 'question': 'How do astronauts prepare before diving into the NBL?', 'source': 'https://nescacademy.nasa.gov/video/2c423fabc80e46bdae08b2401949e3241d', 'text': 'How do astronauts prepare before diving into the NBL? They are briefed on safety, fitted with the Extravehicular Mobility Unit (EMU) suit, adjust weights for neutral buoyancy, and secure their tools with tethers before starting training tasks.'}, page_content='They are briefed on safety, fitted with the Extravehicular Mobility Unit (EMU) suit, adjust weights for neutral buoyancy, and secure their tools with tethers before starting training tasks.'),
#  Document(metadata={'category': 'NBL', 'question': 'Where is the NBL located?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'Where is the NBL located? The Neutral Buoyancy Laboratory is located at the Sonny Carter Training Facility near NASA’s Johnson Space Center in Houston, Texas.'}, page_content='The Neutral Buoyancy Laboratory is located at the Sonny Carter Training Facility near NASA’s Johnson Space Center in Houston, Texas.'),
#  Document(metadata={'category': 'NBL', 'question': 'What suit do astronauts wear in the NBL?', 'source': 'https://www.nasa.gov/suitup', 'text': 'What suit do astronauts wear in the NBL? Astronauts train in the Extravehicular Mobility Unit (EMU), the same type of suit they use during spacewalks on the ISS.'}, page_content='Astronauts train in the Extravehicular Mobility Unit (EMU), the same type of suit they use during spacewalks on the ISS.'),
#  Document(metadata={'category': 'NBL', 'question': 'How do astronauts move underwater in the NBL?', 'source': 'https://appel.nasa.gov/podcast/episode-108-underwater-training-for-astronauts/', 'text': 'How do astronauts move underwater in the NBL? Astronauts use handrails, footholds, and safety tethers attached to full-scale ISS mockups to practice the same movements they would perform during spacewalks.'}, page_content='Astronauts use handrails, footholds, and safety tethers attached to full-scale ISS mockups to practice the same movements they would perform during spacewalks.'),
#  Document(metadata={'category': 'NBL', 'question': 'Who assists astronauts during NBL training?', 'source': 'https://nescacademy.nasa.gov/video/2c423fabc80e46bdae08b2401949e3241d', 'text': 'Who assists astronauts during NBL training? A team of professional divers accompany astronauts during training, monitoring safety, adjusting weights, and assisting if problems occur.'}, page_content='A team of professional divers accompany astronauts during training, monitoring safety, adjusting weights, and assisting if problems occur.'),
#  Document(metadata={'category': 'NBL', 'question': 'How long is a typical NBL training session?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'How long is a typical NBL training session? Each NBL session can last up to six hours, roughly the same length as a real spacewalk, to build endurance and simulate EVA conditions.'}, page_content='Each NBL session can last up to six hours, roughly the same length as a real spacewalk, to build endurance and simulate EVA conditions.'),
#  Document(metadata={'category': 'NBL', 'question': 'What is the role of neutral buoyancy in astronaut training?', 'source': 'https://smv.org/documents/303/Astronaut_Lesson_Plan_Buoyancy.pdf', 'text': 'What is the role of neutral buoyancy in astronaut training? Neutral buoyancy balances an astronaut’s body so they neither sink nor float, creating a close approximation of microgravity to practice EVA tasks.'}, page_content='Neutral buoyancy balances an astronaut’s body so they neither sink nor float, creating a close approximation of microgravity to practice EVA tasks.'),
#  Document(metadata={'category': 'NBL', 'question': 'What kind of ISS structures are inside the NBL?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What kind of ISS structures are inside the NBL? The pool contains full-scale mockups of the International Space Station modules, truss segments, airlocks, and robotic arm components.'}, page_content='The pool contains full-scale mockups of the International Space Station modules, truss segments, airlocks, and robotic arm components.'),
#  Document(metadata={'category': 'NBL', 'question': 'Do astronauts train alone in the NBL?', 'source': 'https://appel.nasa.gov/podcast/episode-108-underwater-training-for-astronauts/', 'text': 'Do astronauts train alone in the NBL? No, astronauts train in teams and always under the supervision of divers, instructors, and mission trainers to simulate real EVA teamwork.'}, page_content='No, astronauts train in teams and always under the supervision of divers, instructors, and mission trainers to simulate real EVA teamwork.'),
#  Document(metadata={'category': 'NBL', 'question': 'What safety measures exist in the NBL?', 'source': 'https://nescacademy.nasa.gov/video/2c423fabc80e46bdae08b2401949e3241d', 'text': 'What safety measures exist in the NBL? Divers accompany astronauts, emergency ascent procedures are practiced, and safety teams monitor the training with underwater cameras and intercom systems.'}, page_content='Divers accompany astronauts, emergency ascent procedures are practiced, and safety teams monitor the training with underwater cameras and intercom systems.'),
#  Document(metadata={'category': 'NBL', 'question': 'What are common astronaut tasks practiced underwater?', 'source': 'https://scitechdaily.com/astronauts-prepare-to-tackle-critical-repairs-in-historic-iss-spacewalk/', 'text': 'What are common astronaut tasks practiced underwater? They practice opening and closing hatches, connecting and disconnecting cables, replacing failed hardware, and installing new components.'}, page_content='They practice opening and closing hatches, connecting and disconnecting cables, replacing failed hardware, and installing new components.'),
#  Document(metadata={'category': 'NBL', 'question': 'How does water drag affect NBL training?', 'source': 'https://pmc.ncbi.nlm.nih.gov/articles/PMC10257652/', 'text': 'How does water drag affect NBL training? Water resistance slows astronaut movements compared to real space, so astronauts must compensate and adjust their techniques during training.'}, page_content='Water resistance slows astronaut movements compared to real space, so astronauts must compensate and adjust their techniques during training.'),
#  Document(metadata={'category': 'NBL', 'question': 'What mental skills are developed during NBL training?', 'source': 'https://appel.nasa.gov/podcast/episode-108-underwater-training-for-astronauts/', 'text': 'What mental skills are developed during NBL training? Astronauts learn patience, concentration, and problem-solving while managing stress in simulated microgravity conditions.'}, page_content='Astronauts learn patience, concentration, and problem-solving while managing stress in simulated microgravity conditions.'),
#  Document(metadata={'category': 'NBL', 'question': 'Do astronauts repeat NBL training after their first mission?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'Do astronauts repeat NBL training after their first mission? Yes, astronauts perform refresher dives to keep their skills sharp and prepare for new tasks or future missions.'}, page_content='Yes, astronauts perform refresher dives to keep their skills sharp and prepare for new tasks or future missions.'),
#  Document(metadata={'category': 'NBL', 'question': 'What happens if an astronaut loses a tool underwater?', 'source': 'https://www.nasa.gov/suitup', 'text': 'What happens if an astronaut loses a tool underwater? Tools are always tethered to prevent them from floating away, but if one is released, divers retrieve it and re-secure it.'}, page_content='Tools are always tethered to prevent them from floating away, but if one is released, divers retrieve it and re-secure it.'),
#  Document(metadata={'category': 'NBL', 'question': 'How do astronauts communicate during NBL training?', 'source': 'https://appel.nasa.gov/podcast/episode-108-underwater-training-for-astronauts/', 'text': 'How do astronauts communicate during NBL training? They use underwater communication systems built into the EMU helmet, talking to each other, divers, and trainers outside the pool.'}, page_content='They use underwater communication systems built into the EMU helmet, talking to each other, divers, and trainers outside the pool.'),
#  Document(metadata={'category': 'NBL', 'question': 'Where is the Neutral Buoyancy Laboratory located?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'Where is the Neutral Buoyancy Laboratory located? The NBL is part of the Sonny Carter Training Facility at NASA’s Johnson Space Center in Houston, Texas.'}, page_content='The NBL is part of the Sonny Carter Training Facility at NASA’s Johnson Space Center in Houston, Texas.'),
#  Document(metadata={'category': 'NBL', 'question': 'What is the NBL mainly used for?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'What is the NBL mainly used for? The NBL supports mission planning, procedure development, hardware verification, astronaut training, and refinement of time-critical operations for successful spacewalks.'}, page_content='The NBL supports mission planning, procedure development, hardware verification, astronaut training, and refinement of time-critical operations for successful spacewalks.'),
#  Document(metadata={'category': 'NBL', 'question': 'What type of water does the NBL pool contain?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'What type of water does the NBL pool contain? The NBL pool contains chlorinated fresh water with a temperature between 84°F and 86°F (28.9°C to 30°C).'}, page_content='The NBL pool contains chlorinated fresh water with a temperature between 84°F and 86°F (28.9°C to 30°C).'),
#  Document(metadata={'category': 'NBL', 'question': 'What unique facility capabilities does the NBL offer?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'What unique facility capabilities does the NBL offer? The NBL includes multiple integrated control rooms, climate-controlled environment, video/audio/instrumentation systems, multiple cranes, SCUBA and surface dive systems, on-site engineering, logistics and manufacturing, ISO level 8 clean room, classrooms, and high-bay work areas.'}, page_content='The NBL includes multiple integrated control rooms, climate-controlled environment, video/audio/instrumentation systems, multiple cranes, SCUBA and surface dive systems, on-site engineering, logistics and manufacturing, ISO level 8 clean room, classrooms, and high-bay work areas.'),
#  Document(metadata={'category': 'NBL', 'question': 'How does diver support work at the NBL?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'How does diver support work at the NBL? The NBL has certified professional divers who provide operations support, reconfiguration, camera operations, and safety diving. The facility includes nitrox and air systems and an on-site hyperbaric chamber.'}, page_content='The NBL has certified professional divers who provide operations support, reconfiguration, camera operations, and safety diving. The facility includes nitrox and air systems and an on-site hyperbaric chamber.'),
#  Document(metadata={'category': 'NBL', 'question': 'How is buoyancy used in NBL training?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'How is buoyancy used in NBL training? The NBL manipulates buoyancy to simulate full or partial gravity, allowing astronauts to practice mass handling underwater in conditions similar to space.'}, page_content='The NBL manipulates buoyancy to simulate full or partial gravity, allowing astronauts to practice mass handling underwater in conditions similar to space.'),
#  Document(metadata={'category': 'NBL', 'question': 'What is the Logistics and Mockup Facility (LMF)?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'What is the Logistics and Mockup Facility (LMF)? The LMF is a high-bay facility with workshops for building and maintaining equipment, offering services such as mockup fabrication, machine shop, welding, sewing, assembly, woodworking, and engineering support.'}, page_content='The LMF is a high-bay facility with workshops for building and maintaining equipment, offering services such as mockup fabrication, machine shop, welding, sewing, assembly, woodworking, and engineering support.'),
#  Document(metadata={'category': 'NBL', 'question': 'What site support does the NBL provide?', 'source': 'https://www.nasa.gov/johnson/frontdoor/', 'text': 'What site support does the NBL provide? The NBL is located near Houston Ellington Airfield with access to a taxiway. It has outdoor and covered storage areas, a hyperbaric chamber, hypobaric altitude chamber, medical treatment room, and locker facilities.'}, page_content='The NBL is located near Houston Ellington Airfield with access to a taxiway. It has outdoor and covered storage areas, a hyperbaric chamber, hypobaric altitude chamber, medical treatment room, and locker facilities.'),
#  Document(metadata={'category': 'EVA', 'question': 'What academic subjects do astronaut candidates study at Johnson Space Center?', 'source': 'https://www.nasa.gov/wp-content/uploads/2017/05/606877main_fs-2011-11-057-jsc-astro_trng.pdf', 'text': 'What academic subjects do astronaut candidates study at Johnson Space Center? Astronaut candidates study physics, mathematics, astronomy, orbital mechanics, meteorology, geology, oceanography, life sciences, technology, and engineering. They complete 16 specialized technical courses.'}, page_content='Astronaut candidates study physics, mathematics, astronomy, orbital mechanics, meteorology, geology, oceanography, life sciences, technology, and engineering. They complete 16 specialized technical courses.'),
#  Document(metadata={'category': 'EVA', 'question': 'Why is orbital navigation important in astronaut training?', 'source': 'https://science.nasa.gov/learn/basics-of-space-flight/chapter13-1/', 'text': 'Why is orbital navigation important in astronaut training? Orbital navigation helps astronauts understand the motion of spacecraft, trajectory planning, orbit determination, and flight path control, enabling them to make critical real-time decisions.'}, page_content='Orbital navigation helps astronauts understand the motion of spacecraft, trajectory planning, orbit determination, and flight path control, enabling them to make critical real-time decisions.'),
#  Document(metadata={'category': 'EVA', 'question': 'What is the role of simulators in astronaut training?', 'source': 'https://www.pbs.org/spacestation/station/training_2.htm', 'text': 'What is the role of simulators in astronaut training? Astronauts use manuals, system trainers, and advanced simulators like Shuttle Mission Simulators to practice spacecraft operations, launch, orbit, docking, and landing procedures, building muscle memory for critical tasks.'}, page_content='Astronauts use manuals, system trainers, and advanced simulators like Shuttle Mission Simulators to practice spacecraft operations, launch, orbit, docking, and landing procedures, building muscle memory for critical tasks.'),
#  Document(metadata={'category': 'EVA', 'question': 'Why is physical fitness essential for astronauts?', 'source': 'https://www.nasa.gov/wp-content/uploads/2018/05/crewstrength_-_teacher.pdf', 'text': 'Why is physical fitness essential for astronauts? Astronauts face muscle atrophy and bone density loss in microgravity. Training includes push-ups, squats, running, and strength exercises to maintain health and prepare for demanding space tasks.'}, page_content='Astronauts face muscle atrophy and bone density loss in microgravity. Training includes push-ups, squats, running, and strength exercises to maintain health and prepare for demanding space tasks.'),
#  Document(metadata={'category': 'EVA', 'question': 'What survival training do astronauts undergo on Earth?', 'source': 'https://mashable.com/feature/nasa-survival-training', 'text': 'What survival training do astronauts undergo on Earth? Astronauts train in deserts, jungles, and oceans to learn survival skills such as finding food and water, building shelters, and handling extreme environments.'}, page_content='Astronauts train in deserts, jungles, and oceans to learn survival skills such as finding food and water, building shelters, and handling extreme environments.'),
#  Document(metadata={'category': 'EVA', 'question': 'How do astronauts train for pressure and altitude adaptation?', 'source': 'https://pvtimes.com/news/apollo-astronauts-conducted-desert-survival-in-nevada-72848/', 'text': 'How do astronauts train for pressure and altitude adaptation? They train in hypobaric and hyperbaric chambers to simulate high and low pressure, and fly in parabolic flights like KC-135 aircraft to experience short periods of weightlessness.'}, page_content='They train in hypobaric and hyperbaric chambers to simulate high and low pressure, and fly in parabolic flights like KC-135 aircraft to experience short periods of weightlessness.'),
#  Document(metadata={'category': 'EVA', 'question': 'What spacecraft do astronauts train to operate today?', 'source': 'https://en.wikipedia.org/wiki/SpaceX_Dragon_2', 'text': 'What spacecraft do astronauts train to operate today? Astronauts train on multiple spacecraft including SpaceX Crew Dragon, learning emergency procedures, launch and docking operations, and practicing inside full-scale mockups.'}, page_content='Astronauts train on multiple spacecraft including SpaceX Crew Dragon, learning emergency procedures, launch and docking operations, and practicing inside full-scale mockups.'),
#  Document(metadata={'category': 'EVA', 'question': 'How do astronauts learn to operate robotic systems?', 'source': 'https://www.asc-csa.gc.ca/eng/iss/canadarm2/', 'text': 'How do astronauts learn to operate robotic systems? They train with robotic arm simulators such as Canadarm2, using high-fidelity devices like the Robotic Work Station (RWS) to practice hand-eye coordination and precise control.'}, page_content='They train with robotic arm simulators such as Canadarm2, using high-fidelity devices like the Robotic Work Station (RWS) to practice hand-eye coordination and precise control.'),
#  Document(metadata={'category': 'EVA', 'question': 'How do astronauts train for medical emergencies in space?', 'source': 'https://cpraedcourse.com/blog/zero-gravity-cpr-techniques/', 'text': 'How do astronauts train for medical emergencies in space? One astronaut per crew is trained as a Crew Medical Officer. They learn CPR techniques adapted for microgravity, like the Evetts-Russomano method, where the rescuer secures themselves with their legs around the patient’s torso.'}, page_content='One astronaut per crew is trained as a Crew Medical Officer. They learn CPR techniques adapted for microgravity, like the Evetts-Russomano method, where the rescuer secures themselves with their legs around the patient’s torso.'),
#  Document(metadata={'category': 'EVA', 'question': 'What psychological training do astronauts receive?', 'source': 'https://medium.com/@humanspaceprogram/psychological-training-for-aspiring-astronauts-a28f2eeaaceb', 'text': 'What psychological training do astronauts receive? They learn stress management, mindfulness, controlled breathing, and mental resilience to cope with isolation, confinement, and mission pressures.'}, page_content='They learn stress management, mindfulness, controlled breathing, and mental resilience to cope with isolation, confinement, and mission pressures.'),
#  Document(metadata={'category': 'EVA', 'question': 'What team-building exercises are used in astronaut training?', 'source': 'https://www.experientiallearning.org/blog/the-nasa-moon-survival-challenge-youre-missing-the-point', 'text': 'What team-building exercises are used in astronaut training? Astronauts participate in exercises like the NASA Moon Survival Challenge, solving group problems, prioritizing survival tools, and practicing teamwork under simulated emergency conditions.'}, page_content='Astronauts participate in exercises like the NASA Moon Survival Challenge, solving group problems, prioritizing survival tools, and practicing teamwork under simulated emergency conditions.'),
#  Document(metadata={'category': 'NASA', 'question': 'What is the overall goal of astronaut training according to NASA?', 'source': 'https://www.nasa.gov/', 'text': 'What is the overall goal of astronaut training according to NASA? Astronaut training integrates applied sciences and human adaptation, focusing on precision, decision-making, and engineering execution across all mission stages.'}, page_content='Astronaut training integrates applied sciences and human adaptation, focusing on precision, decision-making, and engineering execution across all mission stages.'),
#  Document(metadata={'category': 'ISS', 'question': 'What happens during the final countdown before launch?', 'source': 'https://www.nasa.gov/', 'text': 'What happens during the final countdown before launch? During the final countdown, fueling is completed, power is transferred, system checks are done, and liftoff is executed.'}, page_content='During the final countdown, fueling is completed, power is transferred, system checks are done, and liftoff is executed.'),
#  Document(metadata={'category': 'ISS', 'question': 'How long does it take for a spacecraft to dock with the ISS?', 'source': 'https://www.nasa.gov/', 'text': 'How long does it take for a spacecraft to dock with the ISS? Rendezvous and docking with the ISS typically takes 1 to 2 days, involving drift orbit and proximity maneuvers.'}, page_content='Rendezvous and docking with the ISS typically takes 1 to 2 days, involving drift orbit and proximity maneuvers.'),
#  Document(metadata={'category': 'ISS', 'question': 'What is the daily routine of astronauts on the ISS?', 'source': 'https://www.nasa.gov/', 'text': 'What is the daily routine of astronauts on the ISS? Astronauts wake at around 6:00 UTC, have a morning conference with ground control, and complete a 16-hour workday involving science, maintenance, and communication.'}, page_content='Astronauts wake at around 6:00 UTC, have a morning conference with ground control, and complete a 16-hour workday involving science, maintenance, and communication.'),
#  Document(metadata={'category': 'ISS', 'question': 'What scientific experiments are conducted on the ISS?', 'source': 'https://www.nasa.gov/', 'text': 'What scientific experiments are conducted on the ISS? Experiments include biology, fluid dynamics, crystallization, Earth observation, and physics in microgravity.'}, page_content='Experiments include biology, fluid dynamics, crystallization, Earth observation, and physics in microgravity.'),
#  Document(metadata={'category': 'ISS', 'question': 'How do astronauts exercise on the ISS?', 'source': 'https://www.nasa.gov/', 'text': 'How do astronauts exercise on the ISS? Astronauts exercise 2 hours a day, 6 days a week, using ARED for resistance, the COLBERT treadmill, and a cycle ergometer.'}, page_content='Astronauts exercise 2 hours a day, 6 days a week, using ARED for resistance, the COLBERT treadmill, and a cycle ergometer.'),
#  Document(metadata={'category': 'ISS', 'question': 'What are the main hazards astronauts face on the ISS?', 'source': 'https://www.nasa.gov/', 'text': 'What are the main hazards astronauts face on the ISS? Astronauts face hazards including space debris, fire risks, solar storms, and radiation. Emergency protocols include sealing modules and using escape vehicles like Soyuz or Dragon.'}, page_content='Astronauts face hazards including space debris, fire risks, solar storms, and radiation. Emergency protocols include sealing modules and using escape vehicles like Soyuz or Dragon.'),
#  Document(metadata={'category': 'NBL', 'question': 'Does the file focus on NBL training?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'Does the file focus on NBL training? This document primarily focuses on astronaut mission tasks and ISS operations, not on NBL details.'}, page_content='This document primarily focuses on astronaut mission tasks and ISS operations, not on NBL details.'),
#  Document(metadata={'category': 'EVA', 'question': 'Why must astronauts pre-breathe oxygen before EVAs?', 'source': 'https://www.nasa.gov/reference/jsc-eva-systems/', 'text': "Why must astronauts pre-breathe oxygen before EVAs? Astronauts pre-breathe 100% oxygen to avoid decompression sickness, known as 'the bends'."}, page_content="Astronauts pre-breathe 100% oxygen to avoid decompression sickness, known as 'the bends'."),
#  Document(metadata={'category': 'EVA', 'question': 'How has EVA pre-breathing time changed with research?', 'source': 'https://www.nasa.gov/reference/jsc-eva-systems/', 'text': 'How has EVA pre-breathing time changed with research? Protocols evolved from 12 hours of oxygen pre-breathing to about 2 hours with modern methods.'}, page_content='Protocols evolved from 12 hours of oxygen pre-breathing to about 2 hours with modern methods.'),
#  Document(metadata={'category': 'EVA', 'question': 'How long do spacewalks usually last?', 'source': 'https://www.nasa.gov/reference/jsc-eva-systems/', 'text': 'How long do spacewalks usually last? Spacewalks, or EVAs, usually last between 5 and 8 hours depending on the mission.'}, page_content='Spacewalks, or EVAs, usually last between 5 and 8 hours depending on the mission.'),
#  Document(metadata={'category': 'EVA', 'question': 'What are the main objectives of EVA tasks?', 'source': 'https://www.nasa.gov/reference/jsc-eva-systems/', 'text': 'What are the main objectives of EVA tasks? The main objectives of EVAs include installing and repairing station modules, fixing equipment, deploying experiments, and performing scientific tasks.'}, page_content='The main objectives of EVAs include installing and repairing station modules, fixing equipment, deploying experiments, and performing scientific tasks.'),
#  Document(metadata={'category': 'ISS', 'question': 'How many peer-reviewed scientific articles were published by ISS National Lab in fiscal year 2024?', 'source': 'https://issnationallab.org/press-releases/2024-iss-national-lab-scientific-results/', 'text': 'How many peer-reviewed scientific articles were published by ISS National Lab in fiscal year 2024? Over 50 peer-reviewed articles were published in fiscal year 2024, bringing the all-time total to nearly 450 for ISS National Lab-sponsored research.'}, page_content='Over 50 peer-reviewed articles were published in fiscal year 2024, bringing the all-time total to nearly 450 for ISS National Lab-sponsored research.'),
#  Document(metadata={'category': 'ISS', 'question': 'What happened during EVA-91 on ISS in January 2025?', 'source': 'https://www.nasaspaceflight.com/2025/01/iss-roundup-012425/', 'text': 'What happened during EVA-91 on ISS in January 2025? EVA-91 replaced a rate gyro assembly, repaired the NICER telescope, replaced a navigational reflector, imaged debris strikes and prepared for future repairs. The spacewalk lasted about six hours.'}, page_content='EVA-91 replaced a rate gyro assembly, repaired the NICER telescope, replaced a navigational reflector, imaged debris strikes and prepared for future repairs. The spacewalk lasted about six hours.'),
#  Document(metadata={'category': 'ISS', 'question': 'What is EVA-93 known for?', 'source': 'https://www.nasaspaceflight.com/2025/05/iss-eva-93-expedition-73/', 'text': 'What is EVA-93 known for? During EVA-93, astronauts installed part of an iROSA solar panel modification kit on the P4 truss and relocated the C2V2 antenna boom to improve communications for visiting vehicles.'}, page_content='During EVA-93, astronauts installed part of an iROSA solar panel modification kit on the P4 truss and relocated the C2V2 antenna boom to improve communications for visiting vehicles.'),
#  Document(metadata={'category': 'ISS', 'question': 'What is the status of air leaks on ISS as of 2024?', 'source': 'https://www.space.com/iss-leak-50-areas-of-concern-nasa-report', 'text': 'What is the status of air leaks on ISS as of 2024? A persistent air leak in the Russian Zvezda module’s service module transfer tunnel has been ongoing since 2019. In April 2024, it peaked at about 3.7 pounds/day, reduced by patch and repair efforts.'}, page_content='A persistent air leak in the Russian Zvezda module’s service module transfer tunnel has been ongoing since 2019. In April 2024, it peaked at about 3.7 pounds/day, reduced by patch and repair efforts.'),
#  Document(metadata={'category': 'ISS', 'question': 'How many images have astronauts taken from the ISS according to the NASA database up to mid-2025?', 'source': 'https://esrs.jsc.nasa.gov/Tools/DatabaseStats/', 'text': 'How many images have astronauts taken from the ISS according to the NASA database up to mid-2025? Astronauts have taken over 6.4 million images from the ISS catalogued by the NASA database as of June 2025.'}, page_content='Astronauts have taken over 6.4 million images from the ISS catalogued by the NASA database as of June 2025.'),
#  Document(metadata={'category': 'NBL', 'question': 'What new spacesuit was crew-tested for the first time in the NBL in May 2025?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What new spacesuit was crew-tested for the first time in the NBL in May 2025? The Axiom Extravehicular Mobility Unit (AxEMU) was crew-tested for the first time in the NBL by astronaut Koichi Wakata, simulating lunar surface tasks.'}, page_content='The Axiom Extravehicular Mobility Unit (AxEMU) was crew-tested for the first time in the NBL by astronaut Koichi Wakata, simulating lunar surface tasks.'),
#  Document(metadata={'category': 'NBL', 'question': 'What companies completed initial crewed spacesuit tests in the NBL in August 2025?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What companies completed initial crewed spacesuit tests in the NBL in August 2025? KBR and Axiom Space successfully completed three crewed underwater tests of the AxEMU in the NASA NBL pool, validating the suit’s integrity under simulated microgravity.'}, page_content='KBR and Axiom Space successfully completed three crewed underwater tests of the AxEMU in the NASA NBL pool, validating the suit’s integrity under simulated microgravity.'),
#  Document(metadata={'category': 'NBL', 'question': 'What special student program uses the NBL for testing student-built tools?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What special student program uses the NBL for testing student-built tools? The Micro-g Neutral Buoyancy Experiment Design Teams (Micro-g NExT) challenges students to design tools tested in simulated microgravity by divers in the NBL.'}, page_content='The Micro-g Neutral Buoyancy Experiment Design Teams (Micro-g NExT) challenges students to design tools tested in simulated microgravity by divers in the NBL.'),
#  Document(metadata={'category': 'NBL', 'question': 'What modification is planned for the NBL in support of Artemis 2?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What modification is planned for the NBL in support of Artemis 2? NASA and V2X plan to upgrade the NBL by converting part of it into a realistic lunar surface model to support Artemis 2 training.'}, page_content='NASA and V2X plan to upgrade the NBL by converting part of it into a realistic lunar surface model to support Artemis 2 training.'),
#  Document(metadata={'category': 'NBL', 'question': 'How is the NBL used in contractor and commercial suit tests?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'How is the NBL used in contractor and commercial suit tests? Contractors like Axiom and KBR use the NBL for integrated testing of new suits (e.g. AxEMU) to validate communication, breathing and cooling systems in underwater simulated environments.'}, page_content='Contractors like Axiom and KBR use the NBL for integrated testing of new suits (e.g. AxEMU) to validate communication, breathing and cooling systems in underwater simulated environments.'),
#  Document(metadata={'category': 'NBL', 'question': 'What role do divers play in commercial suit test operations in the NBL?', 'source': 'https://www.nasa.gov/johnson/neutral-buoyancy-laboratory/', 'text': 'What role do divers play in commercial suit test operations in the NBL? Divers are trained to support new suit operations by adjusting buoyancy, managing camera systems, and assisting in reconfiguration of training scenarios.'}, page_content='Divers are trained to support new suit operations by adjusting buoyancy, managing camera systems, and assisting in reconfiguration of training scenarios.'),
#  Document(metadata={'category': 'ISS', 'question': 'When was the International Space Station officially approved and by whom?', 'source': 'https://www.nasa.gov/international-space-station/', 'text': 'When was the International Space Station officially approved and by whom? The Space Station was officially approved by President Ronald Reagan and funded by the U.S. Congress in 1984.'}, page_content='The Space Station was officially approved by President Ronald Reagan and funded by the U.S. Congress in 1984.'),
#  Document(metadata={'category': 'ISS', 'question': 'Which countries were the first international partners in the ISS program?', 'source': 'https://www.nasa.gov/international-space-station/', 'text': 'Which countries were the first international partners in the ISS program? Canada, Japan, and European nations from the European Space Agency joined NASA in the late 1980s, with Russia joining in 1993.'}, page_content='Canada, Japan, and European nations from the European Space Agency joined NASA in the late 1980s, with Russia joining in 1993.'),
#  Document(metadata={'category': 'ISS', 'question': 'What was NASA-Mir Phase 1 and when did it occur?', 'source': 'https://www.nasa.gov/international-space-station/', 'text': 'What was NASA-Mir Phase 1 and when did it occur? NASA-Mir Phase 1 took place between 1995 and 1998, involving 11 Shuttle flights to Mir, U.S. experiments on Russian modules, and seven U.S. astronauts living on Mir.'}, page_content='NASA-Mir Phase 1 took place between 1995 and 1998, involving 11 Shuttle flights to Mir, U.S. experiments on Russian modules, and seven U.S. astronauts living on Mir.'),
#  Document(metadata={'category': 'ISS', 'question': 'When did ISS assembly begin and what was the first module?', 'source': 'https://www.nasa.gov/international-space-station/', 'text': 'When did ISS assembly begin and what was the first module? ISS assembly began in 1998 with the launch of Zarya, followed by Unity. The first permanent crew arrived in November 2000.'}, page_content='ISS assembly began in 1998 with the launch of Zarya, followed by Unity. The first permanent crew arrived in November 2000.'),
#  Document(metadata={'category': 'ISS', 'question': 'Which five space agencies operate the ISS?', 'source': 'https://www.nasa.gov/international-space-station/', 'text': 'Which five space agencies operate the ISS? The ISS is operated by NASA (U.S.), Roscosmos (Russia), JAXA (Japan), ESA (Europe), and CSA (Canada).'}, page_content='The ISS is operated by NASA (U.S.), Roscosmos (Russia), JAXA (Japan), ESA (Europe), and CSA (Canada).'),
# ...
#  Document(metadata={'category': 'NASA', 'question': 'What physical fitness requirements must astronaut candidates meet?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What physical fitness requirements must astronaut candidates meet? They must demonstrate good physical conditioning, cardiovascular health, and ability to work under strenuous conditions.'}, page_content='They must demonstrate good physical conditioning, cardiovascular health, and ability to work under strenuous conditions.'),
#  Document(metadata={'category': 'NASA', 'question': 'Does NASA accept candidates with disabilities?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Does NASA accept candidates with disabilities? NASA has strict medical and physical requirements; only candidates who meet all health standards are accepted.'}, page_content='NASA has strict medical and physical requirements; only candidates who meet all health standards are accepted.'),
#  Document(metadata={'category': 'NASA', 'question': 'Are there restrictions on body weight for astronaut selection?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Are there restrictions on body weight for astronaut selection? Yes, body size must allow proper fit in spacecraft seats and spacesuits.'}, page_content='Yes, body size must allow proper fit in spacecraft seats and spacesuits.'),
#  Document(metadata={'category': 'NASA', 'question': 'How long does the NASA astronaut selection process take?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How long does the NASA astronaut selection process take? The selection process usually takes more than a year, including application review, interviews, and medical exams.'}, page_content='The selection process usually takes more than a year, including application review, interviews, and medical exams.'),
#  Document(metadata={'category': 'NASA', 'question': 'How competitive is the NASA astronaut program?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How competitive is the NASA astronaut program? It is extremely competitive. Thousands of applicants apply, but only a few are selected every recruitment cycle.'}, page_content='It is extremely competitive. Thousands of applicants apply, but only a few are selected every recruitment cycle.'),
#  Document(metadata={'category': 'NASA', 'question': 'Where does NASA train selected astronauts?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Where does NASA train selected astronauts? At the Johnson Space Center in Houston, Texas.'}, page_content='At the Johnson Space Center in Houston, Texas.'),
#  Document(metadata={'category': 'NASA', 'question': 'What types of training do NASA astronauts undergo?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What types of training do NASA astronauts undergo? Astronaut training includes spacewalking (EVA), robotics, flight training, language training, and survival training.'}, page_content='Astronaut training includes spacewalking (EVA), robotics, flight training, language training, and survival training.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates need to know Russian?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates need to know Russian? Yes, Russian language training is required to operate and communicate on the ISS.'}, page_content='Yes, Russian language training is required to operate and communicate on the ISS.'),
#  Document(metadata={'category': 'NASA', 'question': 'How long is basic astronaut training at NASA?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How long is basic astronaut training at NASA? Basic training lasts approximately two years.'}, page_content='Basic training lasts approximately two years.'),
#  Document(metadata={'category': 'NASA', 'question': 'What swimming skills must astronaut candidates demonstrate?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What swimming skills must astronaut candidates demonstrate? Candidates must swim three lengths of a 25-meter pool without stopping, then complete three lengths in a flight suit and shoes, followed by treading water for 10 minutes.'}, page_content='Candidates must swim three lengths of a 25-meter pool without stopping, then complete three lengths in a flight suit and shoes, followed by treading water for 10 minutes.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates receive SCUBA training?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates receive SCUBA training? Yes, SCUBA qualification is required for Neutral Buoyancy Laboratory training.'}, page_content='Yes, SCUBA qualification is required for Neutral Buoyancy Laboratory training.'),
#  Document(metadata={'category': 'NASA', 'question': 'What survival training do NASA astronauts complete?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What survival training do NASA astronauts complete? Astronauts train for survival in case of off-course landings, including water and wilderness survival.'}, page_content='Astronauts train for survival in case of off-course landings, including water and wilderness survival.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do NASA astronauts need flight experience?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do NASA astronauts need flight experience? Pilots must have jet flight experience, but mission specialists do not require prior piloting experience.'}, page_content='Pilots must have jet flight experience, but mission specialists do not require prior piloting experience.'),
#  Document(metadata={'category': 'NASA', 'question': 'What psychological requirements does NASA look for?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What psychological requirements does NASA look for? Astronauts must demonstrate resilience, adaptability, teamwork, and ability to operate under stress.'}, page_content='Astronauts must demonstrate resilience, adaptability, teamwork, and ability to operate under stress.'),
#  Document(metadata={'category': 'NASA', 'question': 'Are dental health checks part of astronaut selection?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Are dental health checks part of astronaut selection? Yes, dental health is included in the long-duration spaceflight physical exam.'}, page_content='Yes, dental health is included in the long-duration spaceflight physical exam.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates undergo vision testing in low light?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates undergo vision testing in low light? Yes, candidates must pass low-light and color vision tests.'}, page_content='Yes, candidates must pass low-light and color vision tests.'),
#  Document(metadata={'category': 'NASA', 'question': 'Is hearing tested during astronaut medical exams?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Is hearing tested during astronaut medical exams? Yes, candidates must demonstrate normal hearing ability within NASA standards.'}, page_content='Yes, candidates must demonstrate normal hearing ability within NASA standards.'),
#  Document(metadata={'category': 'NASA', 'question': 'Can people with allergies apply for NASA astronaut selection?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Can people with allergies apply for NASA astronaut selection? Severe allergies or conditions requiring regular medication may disqualify applicants.'}, page_content='Severe allergies or conditions requiring regular medication may disqualify applicants.'),
#  Document(metadata={'category': 'NASA', 'question': 'Can astronauts wear glasses?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Can astronauts wear glasses? Yes, as long as their corrected vision meets NASA standards.'}, page_content='Yes, as long as their corrected vision meets NASA standards.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates have to take psychological tests?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates have to take psychological tests? Yes, extensive psychological testing is part of the selection process.'}, page_content='Yes, extensive psychological testing is part of the selection process.'),
#  Document(metadata={'category': 'NASA', 'question': 'What GPA is required for NASA astronaut applicants?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What GPA is required for NASA astronaut applicants? A strong academic record is expected, though no official minimum GPA is published.'}, page_content='A strong academic record is expected, though no official minimum GPA is published.'),
#  Document(metadata={'category': 'NASA', 'question': 'Can NASA astronauts have tattoos?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Can NASA astronauts have tattoos? Tattoos are not automatically disqualifying, but they must not interfere with professional appearance or equipment use.'}, page_content='Tattoos are not automatically disqualifying, but they must not interfere with professional appearance or equipment use.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates undergo drug testing?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates undergo drug testing? Yes, applicants must pass drug screening.'}, page_content='Yes, applicants must pass drug screening.'),
#  Document(metadata={'category': 'NASA', 'question': 'Can dual citizens apply to become NASA astronauts?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Can dual citizens apply to become NASA astronauts? Yes, if they hold U.S. citizenship. Dual citizenship is acceptable.'}, page_content='Yes, if they hold U.S. citizenship. Dual citizenship is acceptable.'),
#  Document(metadata={'category': 'NASA', 'question': 'How often does NASA open astronaut applications?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How often does NASA open astronaut applications? NASA opens astronaut applications approximately every four years.'}, page_content='NASA opens astronaut applications approximately every four years.'),
#  Document(metadata={'category': 'NASA', 'question': 'How many people typically apply to NASA’s astronaut program?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How many people typically apply to NASA’s astronaut program? Usually more than 10,000 applicants apply in each selection round.'}, page_content='Usually more than 10,000 applicants apply in each selection round.'),
#  Document(metadata={'category': 'NASA', 'question': 'How many applicants are selected in each astronaut class?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How many applicants are selected in each astronaut class? Typically between 10 and 15 candidates are selected per cycle.'}, page_content='Typically between 10 and 15 candidates are selected per cycle.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates train in the Neutral Buoyancy Laboratory (NBL)?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates train in the Neutral Buoyancy Laboratory (NBL)? Yes, EVA and underwater training are key parts of astronaut preparation.'}, page_content='Yes, EVA and underwater training are key parts of astronaut preparation.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do NASA astronauts train with the Russian Soyuz spacecraft?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do NASA astronauts train with the Russian Soyuz spacecraft? Yes, training includes Soyuz systems since it serves as a lifeboat and transport vehicle for ISS missions.'}, page_content='Yes, training includes Soyuz systems since it serves as a lifeboat and transport vehicle for ISS missions.'),
#  Document(metadata={'category': 'NASA', 'question': 'What is the main language of communication on the ISS?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What is the main language of communication on the ISS? Both English and Russian are official languages on the ISS.'}, page_content='Both English and Russian are official languages on the ISS.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do NASA astronauts receive robotics training?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do NASA astronauts receive robotics training? Yes, they train extensively on the Canadarm2 robotic system used on the ISS.'}, page_content='Yes, they train extensively on the Canadarm2 robotic system used on the ISS.'),
#  Document(metadata={'category': 'NASA', 'question': 'How are astronaut candidates evaluated during training?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'How are astronaut candidates evaluated during training? They are assessed on technical knowledge, teamwork, communication, and physical performance.'}, page_content='They are assessed on technical knowledge, teamwork, communication, and physical performance.'),
#  Document(metadata={'category': 'NASA', 'question': 'What swimming strokes are tested during astronaut training?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'What swimming strokes are tested during astronaut training? Candidates are tested using freestyle, backstroke, and breaststroke swimming.'}, page_content='Candidates are tested using freestyle, backstroke, and breaststroke swimming.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do NASA astronauts train for spacewalk emergencies?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do NASA astronauts train for spacewalk emergencies? Yes, training covers contingencies such as suit malfunctions and SAFER jetpack use.'}, page_content='Yes, training covers contingencies such as suit malfunctions and SAFER jetpack use.'),
#  Document(metadata={'category': 'NASA', 'question': 'Are astronauts trained for fire emergencies on spacecraft?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Are astronauts trained for fire emergencies on spacecraft? Yes, they undergo emergency training for fire, depressurization, and toxic atmosphere scenarios.'}, page_content='Yes, they undergo emergency training for fire, depressurization, and toxic atmosphere scenarios.'),
#  Document(metadata={'category': 'NASA', 'question': 'Do astronaut candidates receive leadership training?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Do astronaut candidates receive leadership training? Yes, they train in leadership, teamwork, and communication to prepare for long missions.'}, page_content='Yes, they train in leadership, teamwork, and communication to prepare for long missions.')]

# %%
Chunk[0] ,' -----> ', len(Chunk)
# Out:
# (Document(metadata={'category': 'NASA', 'question': 'What is NASA?', 'answer': 'NASA is the United States government agency responsible for space exploration, aeronautics research, and scientific discovery. It was established in 1958.', 'source': 'https://www.nasa.gov'}, page_content='What is NASA? NASA is the United States government agency responsible for space exploration, aeronautics research, and scientific discovery. It was established in 1958.'),
#  ' -----> ',
#  377)

# %%
Chunk[165].page_content
# Out:
# 'What is SAFER in EVA operations? The Simplified Aid for EVA Rescue is a small backpack with propulsion jets that allows astronauts to maneuver back to safety in emergencies.'

# %%
DOC_Text = [doc.page_content for doc in Chunk]
DOC_Text[20]
# Out:
# 'Astronauts practice repairing ISS components, replacing hardware, installing upgrades, moving along handrails, and using specialized tools underwater.'

# %% [markdown]
# # **Embedding and Indexing**

# %%
# Create embeddings
Embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2",
                                   model_kwargs={'device': 'cpu'},
                                   encode_kwargs={'normalize_embeddings': True})
Embeddings
# Out:
# /tmp/ipykernel_36/3744321175.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   Embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2",
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-mpnet-base-v2', cache_folder=None, model_kwargs={'device': 'cpu'}, encode_kwargs={'normalize_embeddings': True}, multi_process=False, show_progress=False)

# %%
# Create Vector Database
Vector_Database = FAISS.from_documents(Chunk, Embeddings)
Vector_Database

# %%
# Test Search
Query_text = 'Can people with allergies apply for NASA astronaut selection'

sim_docs = Vector_Database.similarity_search(Query_text, k=1)
sim_docs
# Out:
# [Document(id='e90a4837-cdfc-4924-af42-150f16a5a66c', metadata={'category': 'NASA', 'question': 'Can people with allergies apply for NASA astronaut selection?', 'source': 'https://en.wikipedia.org/wiki/List_of_astronauts_by_year_of_selection', 'text': 'Can people with allergies apply for NASA astronaut selection? Severe allergies or conditions requiring regular medication may disqualify applicants.'}, page_content='Severe allergies or conditions requiring regular medication may disqualify applicants.')]

# %% [markdown]
# # **Create Retriever**

# %%
# Retriever
retriever = Vector_Database.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3}
)
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7947a02fc150>, search_kwargs={'k': 3})

# %% [markdown]
# # **Large Language Model (LLM)**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_name = "HuggingFaceH4/zephyr-7b-beta"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype="auto",  
    trust_remote_code=True,
)

# pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    temperature=0.3,
    repetition_penalty=1.1
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
# Hugging Face Pipeline LangChine
LLM = HuggingFacePipeline(pipeline=pipe)
LLM
# Out:
# /tmp/ipykernel_36/2239203584.py:2: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   LLM = HuggingFacePipeline(pipeline=pipe)
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7947a2330610>)

# %%
# Create retriever
retriever = Vector_Database.as_retriever(
            search_type="similarity",
            search_kwargs={"k": 2}
)
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7947a02fc150>, search_kwargs={'k': 2})

# %%
# Prompt Template
template = """
You are a NASA research assistant, specializing in NASA research, the International Space Station (ISS),
the Neutral Buoyancy Laboratory (NBL), and spaceflight.

Your task:
- Use ONLY the context provided to answer the question.
- If multiple pieces of information are found, choose ONLY the one most directly related to the question.
- Answer concisely in one sentence.
- If no relevant information exists, say "I'm not sure".

CONTEXT:
{context}

QUESTION:
{question}

ANSWER:"""

prompt = PromptTemplate(
            input_variables=["context", "question"],
            template=template
        )
prompt
# Out:
# PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\nYou are a NASA research assistant, specializing in NASA research, the International Space Station (ISS),\nthe Neutral Buoyancy Laboratory (NBL), and spaceflight.\n\nYour task:\n- Use ONLY the context provided to answer the question.\n- If multiple pieces of information are found, choose ONLY the one most directly related to the question.\n- Answer concisely in one sentence.\n- If no relevant information exists, say "I\'m not sure".\n\nCONTEXT:\n{context}\n\nQUESTION:\n{question}\n\nANSWER:')

# %%
# Build RetrievalQA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=LLM,
    retriever=retriever,
    chain_type="stuff",
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
qa_chain
# Out:
# RetrievalQA(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\nYou are a NASA research assistant, specializing in NASA research, the International Space Station (ISS),\nthe Neutral Buoyancy Laboratory (NBL), and spaceflight.\n\nYour task:\n- Use ONLY the context provided to answer the question.\n- If multiple pieces of information are found, choose ONLY the one most directly related to the question.\n- Answer concisely in one sentence.\n- If no relevant information exists, say "I\'m not sure".\n\nCONTEXT:\n{context}\n\nQUESTION:\n{question}\n\nANSWER:'), llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7947a2330610>), output_parser=StrOutputParser(), llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], input_types={}, partial_variables={}, template='{page_content}'), document_variable_name='context'), return_source_documents=True, retriever=VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7947a02fc150>, search_kwargs={'k': 2}))

# %%
# Test System
def ask_question(query):
    response = qa_chain.invoke({"query": query})

    answer = response.get("answer") or response.get("result") or response.get("output_text")

    print("Answer:", answer if answer else "⚠️ No answer key found in response.")
    print("\nSources:")

    unique_sources = set()
    for doc in response["source_documents"]:
        source = doc.metadata.get("source", "❓Unknown source")
        category = doc.metadata.get("category", "").strip()

        unique_sources.add((source, category))

    for i, (src, cat) in enumerate(unique_sources, 1):
        print(f"{i}. 🔗 {src} {'| Q: ' + cat if cat else ''}")

# %%
# How do astronauts learn to operate robotic systems
# How big is the NBL?
# What does EVA stand for?
# Can people with allergies apply for NASA astronaut selection
# How much professional experience is required for astronaut candidates
# What are the main strengths of NBL training
# How do astronauts move underwater in the NBL
# What are common astronaut tasks practiced underwater?
# What advantages does the ISS orbit provide for Earth observation?
    
###########################################################################################
    
# Tell me more about NASA
# Tell me more about NBL
# Tell me more about ISS
# Tell me more about Space

ask_question("What advantages does the ISS orbit provide for Earth observation?")
# Out:
# Answer:
# You are a NASA research assistant, specializing in NASA research, the International Space Station (ISS),
# the Neutral Buoyancy Laboratory (NBL), and spaceflight.
#
# Your task:
# - Use ONLY the context provided to answer the question.
# - If multiple pieces of information are found, choose ONLY the one most directly related to the question.
# - Answer concisely in one sentence.
# - If no relevant information exists, say "I'm not sure".
#
# CONTEXT:
# At 250 miles altitude, orbiting at 17,500 mph, the ISS provides detailed views of Earth’s features, weather, and disasters from multiple angles in both daylight and darkness.
#
# The ISS provides access to long-term microgravity, exposure to space, a unique orbit, and hands-on operation by crew members.
#
# QUESTION:
# What advantages does the ISS orbit provide for Earth observation?
#
# ANSWER:
# The ISS's high altitude and fast orbital speed offer detailed views of Earth's features, weather, and disasters from multiple angles in both daylight and darkness for Earth observation.
#
# Sources:
# 1. 🔗 https://www.nasa.gov/international-space-station/space-station-research-and-technology/space-station-science-101/ | Q: Research

# %%
docs = retriever.get_relevant_documents("How much professional experience is required for astronaut candidates")
for i, d in enumerate(docs, 1):
    print(f"{i}. {d.page_content[:300]}...")
    print("Source:", d.metadata.get("source"))
# Out:
# 1. Astronaut candidates study physics, mathematics, astronomy, orbital mechanics, meteorology, geology, oceanography, life sciences, technology, and engineering. They complete 16 specialized technical courses....
# Source: https://www.nasa.gov/wp-content/uploads/2017/05/606877main_fs-2011-11-057-jsc-astro_trng.pdf
# 2. Astronaut training integrates applied sciences and human adaptation, focusing on precision, decision-making, and engineering execution across all mission stages....
# Source: https://www.nasa.gov/
# /tmp/ipykernel_36/1263040152.py:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents("How much professional experience is required for astronaut candidates")

# %% [markdown]
# # **Save Material**

# %%
# Save Vector Database
Vector_Database.save_local("VectorDatabase")

# %%
# Save Model
save_dir = "saved_model"
tokenizer.save_pretrained(save_dir)
model.save_pretrained(save_dir)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3517: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# /tmp/ipykernel_36/2499194893.py in <cell line: 0>()
#       2 save_dir = "saved_model"
#       3 tokenizer.save_pretrained(save_dir)
# ----> 4 model.save_pretrained(save_dir)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    3715                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    3716                 # joyfulness), but for now this enough.
# -> 3717                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    3718             else:
#    3719                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.11/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     284     ```
#     285     """
# --> 286     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     287
#     288
#
# SafetensorError: Error while serializing: IoError(Os { code: 28, kind: StorageFull, message: "No space left on device" })
